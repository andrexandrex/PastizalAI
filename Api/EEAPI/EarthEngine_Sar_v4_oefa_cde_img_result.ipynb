# %% [markdown]
# <table class="ee-notebook-buttons" align="left"><td>
# <a target="_blank"  href="http://colab.research.google.com/github/google/earthengine-community/blob/master/guides/linked/ee-api-colab-setup.ipynb">
#     <img src="https://www.tensorflow.org/images/colab_logo_32px.png" /> Run in Google Colab</a>
# </td><td>
# <a target="_blank"  href="https://github.com/google/earthengine-community/blob/master/guides/linked/ee-api-colab-setup.ipynb"><img width=32px src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" /> View source on GitHub</a></td></table>

# %% [markdown]
# # Earth Engine Python API Colab Setup
#
# This notebook demonstrates how to setup the Earth Engine Python API in Colab and provides several examples of how to print and visualize Earth Engine processed data.

# %% [markdown]
# ## Import API and get credentials
#
# The Earth Engine API is installed by default in Google Colaboratory so requires only importing and authenticating. These steps must be completed for each new Colab session, if you restart your Colab kernel, or if your Colab virtual machine is recycled due to inactivity.

# %% [markdown]
# ### Import the API
#
# Run the following cell to import the API into your session.

# %%
import ee
import pandas as pd
import openpyxl
import ee
import datetime
import os
from PIL import Image
import numpy as np
import json
import IPython.display as disp
import csv

# %% [markdown]
# ### Authenticate and initialize
#
# Run the `ee.Authenticate` function to authenticate your access to Earth Engine servers and `ee.Initialize` to initialize it. Upon running the following cell you'll be asked to grant Earth Engine access to your Google account. Follow the instructions printed to the cell.

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize(project="ee-cima")
print(ee.String('Hello from the Earth Engine servers!').getInfo())
# Out:
# Hello from the Earth Engine servers!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/EEAPI/s1_ard.py"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/EEAPI/terrain_flattening.py"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/EEAPI/helper.py"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/EEAPI/speckle_filter.py"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/EEAPI/border_noise_correction.py"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/EEAPI/wrapper.py"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/oefa_cde_img_result3.csv"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/oefa_cde_img_result3_fullvalues.xlsx"  "/content/"
! cp "/content/drive/Othercomputers/MiPC/Code_OilSpill/Apis/last_dance/LastImages_256_osinergmin.xlsx"  "/content/"

# %%
df = pd.read_excel('/content/LastImages_256_oefa.xlsx')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Original index', 'ID', 'Date and Time', 'Platform',
#        'Instruments', 'Product Type', 'Polarizations', 'Coordinates',
#        'Asset Link', 'Asset Type', 'Unnamed: 0', '...1', 'Nro', 'AÑO', 'Fecha',
#        'Locación', 'Empresa', 'VOLUMEN', 'EXTENSIÓN', 'Tipo de Producto',
#        'departamento', 'ciudad', 'datetime', 'bbox', 'coordinates', 'LON',
#        'LAT', 'geometry', 'bbox_converted'],
#       dtype='object')

# %% [markdown]
# ## Test the API
#
# Coordenadas formato json **ee**

# %% [markdown]
# **SAVE FILES GOOGLE DRIVE**

# %%
import sys
import os
import wrapper as wp

# %%
from IPython.display import Image
import pandas as pd
from datetime import timedelta

# %%
def data_str(df):
    id = df["Original index"]
    return id

# %%
data_str(df)
# Out:
# 0     10
# 1     11
# 2     13
# 3     13
# 4     14
# 5     14
# 6     14
# 7     15
# 8     15
# 9     16
# 10    17
# 11    17
# 12    18
# 13    19
# 14    21
# 15    22
# 16    23
# 17    24
# 18    25
# Name: Original index, dtype: int64

# %%
invalid_rows = df[df['FECHA DE EMERGENCIA AMBIENTAL'].isna()]

# Print the problematic rows
if not invalid_rows.empty:
    print("Rows with invalid or missing dates:")
    print(invalid_rows[['FECHA DE EMERGENCIA AMBIENTAL', 'bbox_converted']])

# Iterate through rows and process valid dates
for index, row in df.iterrows():
    # Check if the date is valid
    if pd.isna(row['FECHA DE EMERGENCIA AMBIENTAL']):
        print(f"Skipping row {index} due to invalid date.")
        continue

    try:
        start_date = pd.to_datetime(row['FECHA DE EMERGENCIA AMBIENTAL'])
        end_date = start_date + timedelta(days=8)
        print(f"Start date: {start_date.strftime('%Y-%m-%d')}")
        print(f"End date: {end_date.strftime('%Y-%m-%d')}")

        # Load coordinates if they exist
        if isinstance(row['bbox_converted'], str):
            coordinates = json.loads(row['bbox_converted'])
            polygon = ee.Geometry.Polygon(coordinates)
            print(f"Polygon info: {polygon.getInfo()}")
        else:
            print(f"Invalid or missing bbox data in row {index}.")

    except Exception as e:
        print(f"Error processing row {index}: {e}")
# Out:
# Start date: 2012-02-16
# End date: 2012-02-24
# Polygon info: {'type': 'Polygon', 'coordinates': [[[-81.
# Polygon info: {'type': 'Polygon', 'coordinates': [[[-81.50373356627492, -4.705971977919619], [-81.27297356627491, -4.705971977919619], [-81.27297356627491, -4.58597197791962], [-81.50373356627492, -4.58597197791962], [-81.50373356627492, -4.705971977919619]]]}
# Start date: 2019-04-02
# End date: 2019-04-10
# Polygon info: {'type': 'Polygon', 'coordinates': [[[-81.5114785747302, -4.722724335406546], [-81.2807185747302, -4.722724335406546], [-81.2807185747302, -4.602724335406546], [-81.5114785747302, -4.602724335406546], [-81.5114785747302, -4.722724335406546]]]}
# Start date: 2019-04-07
# End date: 2019-04-15
# Polygon info: {'type': 'Polygon', 'coordinates': [[[-81.50459894103456, -4.721307086670051], [-81.27383894103455, -4.721307086670051], [-81.27383894103455, -4.601307086670052], [-81.50459894103456, -4.601307086670052], [-81.50459894103456, -4.721307086670051]]]}
# Start date: 2019-04-18
# End date: 2019-04-26
# Polygon info: {'type': 'Polygon', 'coordinates': [[[-81.45266579818909, -4.380956031402163], [-81.22190579818908, -4.380956031402163], [-81.22190579818908, -4.260956031402164], [-81.45266579818909, -4.260956031402164], [-81.45266579818909, -4.380956031402163]]]}
# Start date: 2019-05-11
# End date: 2019-05-19
# Polygon info: {'type': 'Polygon', 'coordinates': [[[-81.51025110450078, -4.714882972083223], [-81.27949110450078, -4.714882972083223], [-81.27949110450078, -4.594882972083224], [-81.51025110450078, -4.594882972083224], [-81.51025110450078, -4.714882972083223]]]}
# Start date: 2019-05-13
# End date: 2019-05-21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d8a4c717c11a> in <cell line: 9>()
#      23             coordinates = json.loads(row['bbox_converted'])
#      24             polygon = ee.Geometry.Polygon(coordinates)
# ---> 25             print(f"Polygon info: {polygon.getInfo()}")
#      26         else:
#      27             print(f"Invalid or missing bbox data in row {index}.")
#
# /usr/local/lib/python3.10/dist-packages/ee/computedobject.py in getInfo(self)
#     105       The object can evaluate to anything.
#     106     """
# --> 107     return data.computeValue(self)
#     108
#     109   def encode(self, encoder: Optional[Callable[..., Any]]) -> Dict[str, Any]:
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in computeValue(obj)
#    1124   _maybe_populate_workload_tag(body)
#    1125
# -> 1126   return _execute_cloud_call(
#    1127       _get_cloud_projects()
#    1128       .value()
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     404   num_retries = _max_retries if num_retries is None else num_retries
#     405   try:
# --> 406     return call.execute(num_retries=num_retries)
#     407   except googleapiclient.errors.HttpError as e:
#     408     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     921
#     922         # Handle retries for server-side errors.
# --> 923         resp, content = _retry_request(
#     924             http,
#     925             num_retries,
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189         try:
#     190             exception = None
# --> 191             resp, content = http.request(uri, method, *args, **kwargs)
#     192         # Retry on SSL errors and socket timeout errors.
#     193         except _ssl_SSLError as ssl_error:
#
# /usr/local/lib/python3.10/dist-packages/google_auth_httplib2.py in request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     216
#     217         # Make the request.
# --> 218         response, content = self.http.request(
#     219             uri,
#     220             method,
#
# /usr/local/lib/python3.10/dist-packages/ee/_cloud_api_utils.py in request(***failed resolving arguments***)
#      68       # requests errors should be converted to kinds that googleapiclient
#      69       # consider transient.
# ---> 70       response = self._session.request(
#      71           method, uri, data=body, headers=headers, timeout=self._timeout
#      72       )
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
log_entries = []
for index, row in df.iterrows():
    # Check and convert dates
    start_date = pd.to_datetime(row['FECHA DE EMERGENCIA AMBIENTAL'], errors='coerce')
    if pd.isna(start_date):
        print(f"Invalid date for row {index}, skipping.")
        continue

    end_date = start_date + timedelta(days=8)

    # Define the ROI
    try:
        roi = ee.Geometry.Polygon(json.loads(row["bbox_converted"]))
    except Exception as e:
        print(f"Error converting bbox for row {index}: {e}")
        continue

    # Define parameter dictionary
    parameter = {
        'START_DATE': start_date.strftime('%Y-%m-%d'),
        'STOP_DATE': end_date.strftime('%Y-%m-%d'),
        'POLARIZATION': 'VV',
        'ROI': roi,
        'APPLY_BORDER_NOISE_CORRECTION': False,
        'APPLY_SPECKLE_FILTERING': True,
        'SPECKLE_FILTER_FRAMEWORK': 'MONO',
        'SPECKLE_FILTER': 'LEE',
        'SPECKLE_FILTER_KERNEL_SIZE': 7,
        'SPECKLE_FILTER_NR_OF_IMAGES': 10,
        'APPLY_TERRAIN_FLATTENING': True,
        'DEM': ee.Image('USGS/SRTMGL1_003'),
        'TERRAIN_FLATTENING_MODEL': 'VOLUME',
        'TERRAIN_FLATTENING_ADDITIONAL_LAYOVER_SHADOW_BUFFER': 0,
        'FORMAT': 'DB',
        'CLIP_TO_ROI': True,
        'SAVE_ASSET': True
    }

    # Call the preprocessing function
    wp.s1_preproc(parameter, df["Original index"][index])

    log_entries.append({
        'file_name': f'{start_date.strftime("%Y%m%d")}_S1_GRD',
        'location': f'{row["bbox_converted"]}',
        'time': start_date.strftime('%Y-%m-%d')
    })
    print(f'Processed data for event on {start_date.strftime("%Y-%m-%d")}')
# Out:
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2012-02-16
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SSV_20150316T234352_20150316T234417_005063_0065C1_5F75
# Exporting 1_2015-03-16_S1_GRD to oefa_img_v3
# Processed data for event on 2015-03-14
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2016-01-05
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20180605T233314_20180605T233343_011244_014A37_4EC7
# Exporting 3_2018-06-05_S1_GRD to oefa_img_v3
# Processed data for event on 2018-06-05
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2018-10-11
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2019-05-26
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2020-09-18
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20240127T104804_20240127T104825_052291_06527C_A0F8
# Exporting 8_2024-01-27_S1_GRD to oefa_img_v3
# Processed data for event on 2024-01-24
# Number of images in collection:  2
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20240115T104804_20240115T104825_052116_064C99_AEC3
# Exporting 9_2024-01-15_S1_GRD to oefa_img_v3
# S1A_IW_GRDH_1SDV_20240122T103945_20240122T104010_052218_065007_C2C3
# Exporting 9_2024-01-22_S1_GRD to oefa_img_v3
# Processed data for event on 2024-01-15
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2014-01-08
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2014-06-01
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2014-09-22
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2013-05-01
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2013-07-04
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2014-04-02
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2014-09-08
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20170718T110114_20170718T110139_006541_00B809_7EEB
# Exporting 17_2017-07-18_S1_GRD to oefa_img_v3
# Processed data for event on 2017-07-11
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2018-11-27
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20181219T234351_20181219T234416_014117_01A39F_FCA4
# Exporting 21_2018-12-19_S1_GRD to oefa_img_v3
# Processed data for event on 2018-12-19
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20190124T234349_20190124T234414_014642_01B4A7_F06A
# Exporting 22_2019-01-24_S1_GRD to oefa_img_v3
# Processed data for event on 2019-01-23
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20190205T234324_20190205T234349_014817_01BA68_B23B
# Exporting 23_2019-02-05_S1_GRD to oefa_img_v3
# Processed data for event on 2019-02-01
# Number of images in collection:  2
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20190217T234324_20190217T234349_014992_01C027_9E4F
# Exporting 24_2019-02-17_S1_GRD to oefa_img_v3
# S1B_IW_GRDH_1SDV_20190217T234349_20190217T234414_014992_01C027_2D58
# Exporting 24_2019-02-17_S1_GRD to oefa_img_v3
# Processed data for event on 2019-02-11
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2019-03-10
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2019-03-12
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2019-03-16
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20190406T234324_20190406T234349_015692_01D718_62E2
# Exporting 28_2019-04-06_S1_GRD to oefa_img_v3
# Processed data for event on 2019-04-02
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2019-04-07
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2020-10-24
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2020-11-19
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20210113T234337_20210113T234402_025142_02FE5A_F849
# Exporting 114_2021-01-13_S1_GRD to oefa_img_v3
# Processed data for event on 2021-01-09
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-01-27
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-02-05
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-02-05
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-02-10
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-02-23
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-02-28
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-03-08
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20210501T234402_20210501T234427_026717_033104_010A
# Exporting 122_2021-05-01_S1_GRD to oefa_img_v3
# Processed data for event on 2021-04-28
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1B_IW_GRDH_1SDV_20210522T110136_20210522T110201_027016_033A47_BDAB
# Exporting 123_2021-05-22_S1_GRD to oefa_img_v3
# Processed data for event on 2021-05-17
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-11-02
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-11-04
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2021-11-05
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2022-02-18
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2022-03-29
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2022-07-02
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20220830T234444_20220830T234509_044788_055940_AFAE
# Exporting 130_2022-08-30_S1_GRD to oefa_img_v3
# Processed data for event on 2022-08-24
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2022-10-07
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20230729T110223_20230729T110248_049637_05F804_FAF0
# Exporting 132_2023-07-29_S1_GRD to oefa_img_v3
# Processed data for event on 2023-07-22
# Number of images in collection:  2
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20230822T110224_20230822T110249_049987_060388_FB06
# Exporting 133_2023-08-22_S1_GRD to oefa_img_v3
# S1A_IW_GRDH_1SDV_20230825T234449_20230825T234514_050038_060543_C50A
# Exporting 133_2023-08-25_S1_GRD to oefa_img_v3
# Processed data for event on 2023-08-18
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20230226T234441_20230226T234506_047413_05B11B_565E
# Exporting 134_2023-02-26_S1_GRD to oefa_img_v3
# Processed data for event on 2023-02-23
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20230226T234441_20230226T234506_047413_05B11B_565E
# Exporting 135_2023-02-26_S1_GRD to oefa_img_v3
# Processed data for event on 2023-02-23
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20230226T234441_20230226T234506_047413_05B11B_565E
# Exporting 136_2023-02-26_S1_GRD to oefa_img_v3
# Processed data for event on 2023-02-23
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20230427T234442_20230427T234507_048288_05CE9B_1D0E
# Exporting 137_2023-04-27_S1_GRD to oefa_img_v3
# Processed data for event on 2023-04-20
# Number of images in collection:  1
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# S1A_IW_GRDH_1SDV_20230427T234442_20230427T234507_048288_05CE9B_1D0E
# Exporting 138_2023-04-27_S1_GRD to oefa_img_v3
# Processed data for event on 2023-04-20
# Number of images in collection:  0
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Processed data for event on 2015-05-15

# %%
log_entries = []
for index, row in df.iterrows():
    start_date = pd.to_datetime(row['Fecha']) - timedelta(days=2)
    end_date = start_date + timedelta(days=5)
    roi
    log_entries.append({
        'file_name': f'{start_date.strftime("%Y%m%d")}_S1_GRD',
        'location': f'{ee.Geometry.Rectangle(json.loads(row["bbox"]))}',
        'time': start_date.strftime('%Y-%m-%d')
    })
print(log_entries)
# Out:
# [{'file_name': '20041215_S1_GRD', 'location': 'ee.Geometry({\n  "functionInvocationValue": {\n    "functionName": "GeometryConstructors.Polygon",\n    "arguments": {\n      "coordinates": {\n        "constantValue": [\n          [\n            [\n              -81.3318335,\n              -4.519687200000001\n            ],\n            [\n              -81.3318335,\n              -4.6396872\n            ],\n            [\n              -81.2718335,\n              -4.6396872\n            ],\n            [\n              -81.2718335,\n              -4.519687200000001\n            ]\n          ]\n        ]\n      },\n      "evenOdd": {\n        "constantValue": true\n      }\n    }\n  }\n})', 'time': '2004-12-15'}, {'file_name': '20090824_S1_GRD', 'location': 'ee.Geometry({\n  "functionInvocationValue": {\n    "functionName": "GeometryConstructors.Polygon",\n    "arguments": {\n      "coordinates": {\n        "constantValue": [\n          [\n            [\n              -81.3318335,\n              -4.519687200000001\n            ],\n            [\n              -81.3318335,\n              -4.6396872\n            ],\n            [\n              -81.2718335,\n              -4.6396872\n            ],\n            [\n              -81.2718335,\n              -4.519687200000001\n            ]\n          ]\n        ]\n      },\n      "evenOdd": {\n        "constantValue": true\n      }\n    }\n  }\n})', 'time': '2009-08-24'}, {'file_name': '20091025_S1_GRD', 'location': 'ee.Geometry({\n  "functionInvocationValue": {\n    "functionName": "GeometryConstructors.Polygon",\n    "arguments": {\n      "coordinates": {\n        "constantValue": [\n          [\n            [\n              -81.3318335,\n              -4.519687200000001\n            ],\n            [\n              -81.3318335,\n              -4.6396872\n            ],\n            [\n              -81.2718335,\n              -4.6396872\n            ],\n            [\n              -81.2718335,\n              -4.519687200000001\n            ]\n          ]\n        ]\n      },\n      "evenOdd": {\n        "constantValue": true\n      }\n    }\n  }\n})', 'time': '2009-10-25'}, {'file_name': '20110124_S1_GRD', 'location': 'ee.Geometry({\n  "functionInvocationValue": {\n    "functionName": "GeometryConstructors.Polygon",\n    "arguments": {\n      "coordinates": {\n        "constantValue": [\n          [\n            [\n              -81.0333735,\n              -4.9499903000000005\n            ],\n            [\n              -81.0333735,\n              -5.0699903\n            ],\n            [\n              -80.9733735,\n              -5.0699903\n            ],\n            [\n              -80.9733735,\n              -4.9499903000000005\n            ]\n          ]\n        ]\n      },\n      "evenOdd": {\n        "constantValue": true\n      }\n    }\n  }\n})', 'time': '2011-01-24'}, {'file_name': '20130202_S1_GRD', 'location': 'ee.Geometry({\n  "functionInvocationValue": {\n    "functionName": "GeometryConstructors.Polygon",\n    "arguments": {\n      "coordinates": {\n        "constantValue": [\n          [\n            [\n              -77.22222980000001,\n              -11.7687168\n            ],\n            [\n              -77.22222980000001,\n              -11.888716800000001\n            ],\n            [\n              -77.1622298,\n              -11.888716800000001\n            ],\n            [\n              -77.1622298,\n              -11.7687168\n            ]\n          ]\n        ]\n      },\n      "evenOdd": {\n        "constantValue": true\n      }\n    }\n  }\n})', 'time': '2013-02-02'}, {'file_name': '20130429_S1_GRD', 'location': 'ee.Geometry({\n  "functionInvocationValue": {\n    "functionName": "GeometryConstructors.Polygon",\n    "arguments": {\n      "coordinates": {\n        "constantValue": [\n          [\n            [\n              -81.3318335,\n              -4.519687200000001\n            ],\n            [\n              -81.3318335,\n             ...

# %%
len(log_entries)
# Out:
# 69

# %%
parameter = {'START_DATE': '2018-01-01',
            'STOP_DATE': '2018-02-01',
            'POLARIZATION': 'VV',
            'ORBIT' : 'BOTH',
            'PLATFORM_NUMBER' : 'A',
            'ORBIT_NUM': None,
            'ROI': ee.Geometry.Rectangle([-47.1634, -3.00071, -45.92746, -5.43836]),
            'APPLY_BORDER_NOISE_CORRECTION': False,
            'APPLY_SPECKLE_FILTERING': True,
            'SPECKLE_FILTER_FRAMEWORK':'MONO',
            'SPECKLE_FILTER': 'LEE',
            'SPECKLE_FILTER_KERNEL_SIZE': 7,
            'SPECKLE_FILTER_NR_OF_IMAGES':10,
            'APPLY_TERRAIN_FLATTENING': True,
            'DEM': ee.Image('USGS/SRTMGL1_003'),
            'TERRAIN_FLATTENING_MODEL': 'VOLUME',
            'TERRAIN_FLATTENING_ADDITIONAL_LAYOVER_SHADOW_BUFFER':0,
            'FORMAT': 'DB',
            'CLIP_TO_ROI': True,
            'SAVE_ASSET': True
            }

    log_entries.append({
        'file_name': f'{start_date.strftime("%Y%m%d")}_S1_GRD',
        'location': f'{row["bbox_converted"]}',
        'time': start_date.strftime('%Y-%m-%d')
    })

wp.s1_preproc(parameter)
# Out:
# Number of images in collection:  13
# Mono-temporal speckle filtering is completed
# Radiometric terrain normalization is completed
# Exporting S1A_IW_GRDH_1SDV_20180107T084137_20180107T084202_020046_022281_87D2 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180107T084202_20180107T084227_020046_022281_1045 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180107T084227_20180107T084252_020046_022281_EA84 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180112T084946_20180112T085011_020119_0224E5_2A8F to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180112T085011_20180112T085036_020119_0224E5_EF72 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180119T084137_20180119T084202_020221_02280E_5674 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180119T084202_20180119T084227_020221_02280E_8D56 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180119T084227_20180119T084252_020221_02280E_3A38 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180124T084946_20180124T085011_020294_022A74_263C to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180124T085011_20180124T085036_020294_022A74_A2B5 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180131T084136_20180131T084201_020396_022D9D_3924 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180131T084201_20180131T084226_020396_022D9D_DFB2 to GEE_SAR_processed
# Exporting S1A_IW_GRDH_1SDV_20180131T084226_20180131T084251_020396_022D9D_DE6D to GEE_SAR_processed

# %%
task.status()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 task.status()
#
# NameError: name 'task' is not defined

# %%
first_image = s1_processed.first()
first_image

# %%
# Fetch and print the image metadata
metadata = first_image.getInfo()
print(metadata)
# Out:
# {'type': 'Image', 'bands': [{'id': 'VV', 'data_type': {'type': 'PixelType', 'precision': 'double'}, 'dimensions': [28724, 22174], 'origin': [0, 1], 'crs': 'EPSG:32723', 'crs_transform': [10, 0, 330129.7609730883, 0, -10, 9738702.70357257]}, {'id': 'angle', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [21, 10], 'crs': 'EPSG:32723', 'crs_transform': [-12553.2307824397, -4308.04279434518, 617369.086477932, 2730.286116309464, -20051.85848106444, 9684077.970874848]}], 'properties': {'SLC_Processing_software_name': 'Sentinel-1 IPF', 'sliceProductFlag': 'true', 'S1TBX_Calibration_vers': '6.0.4', 'orbitNumber_start': 20046, 'GRD_Post_Processing_start': 1515322414640, 'sliceNumber': 2, 'GRD_Post_Processing_facility_site': 'Airbus DS-Newport', 'instrument': 'Synthetic Aperture Radar', 'GRD_Post_Processing_facility_name': 'Copernicus S1 Core Ground Segment - UPA', 'resolution': 'H', 'SLC_Processing_facility_name': 'Copernicus S1 Core Ground Segment - UPA', 'GRD_Post_Processing_software_name': 'Sentinel-1 IPF', 'familyName': 'SENTINEL-1', 'platform_number': 'A', 'S1TBX_SAR_Processing_vers': '6.0.4', 'segmentStartTime': 1515314469080, 'productType': 'GRD', 'missionDataTakeID': 139905, 'GRD_Post_Processing_facility_country': 'United Kingdom', 'nssdcIdentifier': '2014-016A', 'productClass': 'S', 'phaseIdentifier': 1, 'orbitProperties_ascendingNodeTime': 1515311481280, 'stopTimeANX': 3041494, 'orbitProperties_pass': 'DESCENDING', 'relativeOrbitNumber_stop': 24, 'productComposition': 'Slice', 'productClassDescription': 'SAR Standard L1 Product', 'SLC_Processing_facility_site': 'Airbus DS-Newport', 'GRD_Post_Processing_software_version': '002.84', 'GRD_Post_Processing_stop': 1515323047000, 'system:time_start': 1515314497000, 'SLC_Processing_software_version': '002.84', 'orbitNumber_stop': 20046, 'instrumentMode': 'IW', 'totalSlices': 12, 'instrumentConfigurationID': 6, 'SLC_Processing_stop': 1515322834000, 'startTimeANX': 3016496, 'SLC_Processing_start': 1515322520000, 'resolution_meters': 10, 'instrumentSwath': 'IW', 'relativeOrbitNumber_start': 24, 'productTimelinessCategory': 'Fast-24h', 'cycleNumber': 129, 'system:index': 'S1A_IW_GRDH_1SDV_20180107T084137_20180107T084202_020046_022281_87D2', 'SNAP_Graph_Processing_Framework_GPF_vers': '6.0.4', 'SLC_Processing_facility_org': 'ESA', 'SLC_Processing_facility_country': 'United Kingdom', 'GRD_Post_Processing_facility_org': 'ESA', 'transmitterReceiverPolarisation': ['VV', 'VH']}}

# %%
# Print specific properties
acquisition_date = first_image.date().format().getInfo()
print("Acquisition Date:", acquisition_date)

# Example to fetch and print projection information
projection = first_image.select('VV').projection().getInfo()
print("Projection Information:", projection)

# Getting band information
band_info = first_image.bandNames().getInfo()
print("Band Names:", band_info)
# Out:
# Acquisition Date: 2018-01-07T08:41:37
# Projection Information: {'type': 'Projection', 'crs': 'EPSG:32723', 'transform': [10, 0, 330129.7609730883, 0, -10, 9738702.70357257]}
# Band Names: ['VV', 'angle']

# %%
vv_band = first_image.select('VV')

# %%
vv_band

# %%
link = first_image.getDownloadURL({
    'scale': 352,
    'crs': 'EPSG:4326',
    'fileFormat': "GeoTIFF",
    'region': first_image.geometry().coordinates().getInfo()})
print(link)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     401   try:
# --> 402     return call.execute(num_retries=num_retries)
#     403   except googleapiclient.errors.HttpError as e:
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-cima/thumbnails?fields=name&alt=json returned "Pixel grid dimensions (9699311x8154615) must be less than or equal to 32768.". Details: "Pixel grid dimensions (9699311x8154615) must be less than or equal to 32768.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-21-c3758f991923> in <cell line: 1>()
# ----> 1 link = first_image.getDownloadURL({
#       2     'scale': 352,
#       3     'crs': 'EPSG:4326',
#       4     'fileFormat': "GeoTIFF",
#       5     'region': first_image.geometry().coordinates().getInfo()})
#
# /usr/local/lib/python3.10/dist-packages/ee/image.py in getDownloadURL(self, params)
#     477     request = params or {}
#     478     request['image'] = self
# --> 479     return data.makeDownloadUrl(data.getDownloadId(request))
#     480
#     481   def getThumbId(self, params: Dict[str, Any]) -> Dict[str, str]:
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in getDownloadId(params)
#    1353   }
#    1354   _maybe_populate_workload_tag(queryParams)
# -> 1355   result = _execute_cloud_call(
#    1356       _get_cloud_projects()
#    1357       .thumbnails()
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     402     return call.execute(num_retries=num_retries)
#     403   except googleapiclient.errors.HttpError as e:
# --> 404     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#     405
#     406
#
# EEException: Pixel grid dimensions (9699311x8154615) must be less than or equal to 32768.

# %%
# Define a smaller region
smaller_region = ee.Geometry.Rectangle([-81.31, -4.63, -81.29, -4.61])

link = first_image.getDownloadURL({
    'scale': 10,
    'crs': 'EPSG:4326',
    'fileFormat': "GeoTIFF",
    'region': smaller_region.coordinates().getInfo()
})
print(link)
# Out:
# https://earthengine.googleapis.com/v1/projects/ee-cima/thumbnails/e8a13dba1b659f51705fc30f2f52a615-41f6cc96c6b6988f55dbcfe1c7aa6da0:getPixels

# %%
link = first_image.getDownloadURL({
    'fileFormat': 'GeoTIFF',
    'region': first_image.geometry()})
print(link)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     401   try:
# --> 402     return call.execute(num_retries=num_retries)
#     403   except googleapiclient.errors.HttpError as e:
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-cima/thumbnails?fields=name&alt=json returned "Total request size (1437868918 bytes) must be less than or equal to 50331648 bytes.". Details: "Total request size (1437868918 bytes) must be less than or equal to 50331648 bytes.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-167-de23c55dadfb> in <cell line: 1>()
# ----> 1 link = first_image.getDownloadURL({
#       2     'fileFormat': 'GeoTIFF',
#       3     'region': ee.Geometry.Rectangle([-47.1634, -3.00071, -45.92746, -5.43836])})
#       4 print(link)
#
# /usr/local/lib/python3.10/dist-packages/ee/image.py in getDownloadURL(self, params)
#     477     request = params or {}
#     478     request['image'] = self
# --> 479     return data.makeDownloadUrl(data.getDownloadId(request))
#     480
#     481   def getThumbId(self, params: Dict[str, Any]) -> Dict[str, str]:
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in getDownloadId(params)
#    1353   }
#    1354   _maybe_populate_workload_tag(queryParams)
# -> 1355   result = _execute_cloud_call(
#    1356       _get_cloud_projects()
#    1357       .thumbnails()
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     402     return call.execute(num_retries=num_retries)
#     403   except googleapiclient.errors.HttpError as e:
# --> 404     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#     405
#     406
#
# EEException: Total request size (1437868918 bytes) must be less than or equal to 50331648 bytes.

# %%
manual_region = ee.Geometry.Rectangle([-81.3318335, -4.6396872, -81.2718335, -4.5196872])

# %%
f_32 = first_image.toFloat()
task = ee.batch.Export.image.toDrive(image=f_32,
                                     description='elevation_near_lyon_france',
                                     scale=30,
                                     region=f_32.geometry(),
                                     folder='GEE_Folder',
                                     crs='EPSG:4326')
task.start()

# %%
task.status()
# Out:
# {'state': 'COMPLETED',
#  'description': 'elevation_near_lyon_france',
#  'priority': 100,
#  'creation_timestamp_ms': 1713747086415,
#  'update_timestamp_ms': 1713747667333,
#  'start_timestamp_ms': 1713747092456,
#  'task_type': 'EXPORT_IMAGE',
#  'destination_uris': ['https://drive.google.com/#folders/1gfzDvoYPs4fUUuvUNZkHdyon3GcrNplV'],
#  'attempt': 1,
#  'batch_eecu_usage_seconds': 8475.474609375,
#  'id': '6MVBJMXQFULVXZ63X5WZFT7H',
#  'name': 'projects/ee-cima/operations/6MVBJMXQFULVXZ63X5WZFT7H'}

# %%
link = f_32.getDownloadURL({
    'crs': 'EPSG:4326',
    'fileFormat': 'GeoTIFF',
    'region': f_32.geometry()})
print(link)
# Out:
# https://earthengine.googleapis.com/v1/projects/ee-cima/thumbnails/f508d3d7e7fd11211763c65522990e59-8e52e5d22e9ee2e506517beefcc01db8:getPixels
